# %%
samp_state=['maharashtra','tamil nadu','delhi','gujarat','uttar pradesh','rajasthan','west bengal','madhya pradesh','haryana','karnataka','andhra pradesh','bihar','telangana','jammu and kashmir','assam','odisha','punjab','kerala','uttarakhand','chhattisgarh','jharkhand','tripura','ladakh','goa','himachal pradesh','manipur','chandigarh','puducherry','nagaland','mizoram','arunachal pradesh','sikkim','dadra and nagar haveli and daman and diu','andaman and nicobar islands','meghalaya','state unassigned']
data=[]
f=open("covid_data2.txt",'r')
for i in f:
    data.append(i.rstrip())
#print(data)
f.close()
country_cases=[]
state_data=[]
district_data=[]
i=1
country_cases.append(data[i:i+4])    
for i in range(10,len(data)):
    if data[i].lower() in samp_state:
        state_data.append(data[i:i+5])
        i+=5
    elif(data[i].lower()=='districts'):
        new=[]
        i+=5
        k=0
        while(k==0):
            if(data[i]=='end'):
                k=1
            elif(data[i+1].lower()=='districts'):
                k=1
            elif data[i].lower() in samp_state:
                k=1
                i-=1
                district_data.append(new)
            else:
                new.append(data[i:i+5])
                i+=5
#print(district_data[10])       
#print(state_data)
#print(country_cases)
from tkinter import *
import tkinter as tk
global fh
root=Tk()
root.title("Covid-19")
fh=Frame(root,bg="black")
fh.pack(fill=BOTH,expand=True)
im=PhotoImage(file="pic1.png")
label=Label(fh,image=im).place(x=1250,y=0)
Label(root,text="Covid-19-India",bg="black",fg="white",font=("Algerian",50,"bold")).place(x=0,y=10)
Label(root,text="- Team:\nHunTer_SQuaD",bg="black",fg="white",font=("Algerian",15,"bold")).place(x=1350,y=770)
frame=Frame(root,bg="black",height=700,width=1000,borderwidth=1)
global frame2
def callback(n,o):
    import matplotlib.pyplot as plt
    import os
    frame1=Frame(root,bg="white",height=700,width=1000,borderwidth=1)
    Label(frame1,text=o,bg="black",fg="white",font=("Lucida Bright",15,"bold underline"),width=30,anchor='w').grid(row=1,column=0)
    Label(frame1,text="Total Cases:"+"      "+state_data[n][1],bg="black",fg="yellow",font=("Lucida Bright",15,"bold"),width=30,anchor='w').grid(row=2,column=0)
    Label(frame1,text="Recovered:"+"      "+state_data[n][2],bg="black",fg="light green",font=("Lucida Bright",15,"bold"),width=30,anchor='w').grid(row=3,column=0)
    Label(frame1,text="Active Cases:"+"      "+state_data[n][3],bg="black",fg="sky blue",font=("Lucida Bright",15,"bold"),width=30,anchor='w').grid(row=4,column=0)
    Label(frame1,text="Total deaths:"+"      "+state_data[n][4],bg="black",fg="red",font=("Lucida Bright",15,"bold"),width=30,anchor='w').grid(row=5,column=0)
    frame2=Frame(root,bg="white",height=700,width=1000,borderwidth=1)
    frame2.place_forget()
    for i in range(len(district_data[n])):
        for j in range(4):
            btn=Button(frame2,text=(district_data[n])[i][j],bg="black",fg="white",bd=1,activebackground="black",font=("Lucida Bright",6,"bold"),width=30,anchor='w').grid(row=i,column=j)
    frame1.place(x=0,y=610)
    frame2.place(x=500,y=10)
def samp(k):
    pass
j=1
Button(frame,text=state_data[0][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command= lambda: callback(0,state_data[0][0])).grid(row=0,column=j)
Button(frame,text=state_data[1][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(1,state_data[1][0])).grid(row=1,column=j)
Button(frame,text=state_data[2][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(2,state_data[2][0])).grid(row=2,column=j)
Button(frame,text=state_data[3][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(3,state_data[3][0])).grid(row=3,column=j)
Button(frame,text=state_data[4][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(4,state_data[4][0])).grid(row=4,column=j)
Button(frame,text=state_data[5][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(5,state_data[5][0])).grid(row=5,column=j)
Button(frame,text=state_data[6][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(6,state_data[6][0])).grid(row=6,column=j)
Button(frame,text=state_data[7][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(7,state_data[7][0])).grid(row=7,column=j)
Button(frame,text=state_data[8][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(8,state_data[8][0])).grid(row=8,column=j)
Button(frame,text=state_data[9][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(9,state_data[9][0])).grid(row=9,column=j)
Button(frame,text=state_data[10][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(10,state_data[10][0])).grid(row=10,column=j)
Button(frame,text=state_data[11][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(11,state_data[11][0])).grid(row=11,column=j)
Button(frame,text=state_data[12][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(12,state_data[12][0])).grid(row=12,column=j)
Button(frame,text=state_data[13][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(13,state_data[13][0])).grid(row=13,column=j)
Button(frame,text=state_data[14][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(14,state_data[14][0])).grid(row=14,column=j)
Button(frame,text=state_data[15][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(15,state_data[15][0])).grid(row=15,column=j)
Button(frame,text=state_data[16][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(16,state_data[16][0])).grid(row=16,column=j)
Button(frame,text=state_data[17][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(17,state_data[17][0])).grid(row=17,column=j)
Button(frame,text=state_data[18][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(18,state_data[18][0])).grid(row=0,column=2)
Button(frame,text=state_data[19][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(19,state_data[19][0])).grid(row=1,column=2)
Button(frame,text=state_data[20][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(20,state_data[20][0])).grid(row=2,column=2)
Button(frame,text=state_data[21][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(21,state_data[21][0])).grid(row=3,column=2)
Button(frame,text=state_data[22][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(22,state_data[22][0])).grid(row=4,column=2)
Button(frame,text=state_data[23][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(23,state_data[23][0])).grid(row=5,column=2)
Button(frame,text=state_data[24][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(24,state_data[24][0])).grid(row=6,column=2)
Button(frame,text=state_data[25][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(25,state_data[25][0])).grid(row=7,column=2)
Button(frame,text=state_data[26][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(26,state_data[26][0])).grid(row=8,column=2)
Button(frame,text=state_data[27][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(27,state_data[27][0])).grid(row=9,column=2)
Button(frame,text=state_data[28][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(28,state_data[28])).grid(row=10,column=2)
Button(frame,text=state_data[29][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(29,state_data[29][0])).grid(row=11,column=2)
Button(frame,text=state_data[30][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(30,state_data[30][0])).grid(row=12,column=2)
Button(frame,text=state_data[31][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(31,state_data[31][0])).grid(row=13,column=2)
Button(frame,text=state_data[32][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(32,state_data[33][0])).grid(row=14,column=2)
Button(frame,text=state_data[33][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(33,state_data[34][0])).grid(row=15,column=2)
Button(frame,text=state_data[34][0],width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=lambda: callback(34,state_data[35][0])).grid(row=16,column=2)
Button(frame,text="Unsigned State",width=30,height=1,bd=3,bg="black",fg="yellow",font=("Lucida Bright",10,"bold"),activebackground="grey",command=samp(2)).grid(row=17,column=2)

frame.place(x=0,y=100)
root.mainloop()
